# %% [markdown]
# <a href="https://colab.research.google.com/github/PACFWL/DataMining/blob/main/MineracaodeDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


df = pd.read_csv('Fruit Sales Data.csv')

df.head()
# Out:
#    Fruit Name  Weight in Kg  Total Cost Purchased
# 0       Apple          44.0     72000.0        No
# 1       Mango          27.0     48000.0       Yes
# 2      Orange          30.0     54000.0        No
# 3  Strawberry          38.0     61000.0        No
# 4      Orange          40.0         NaN       Yes

# %%
df.dtypes
# Out:
# Fruit Name       object
# Weight in Kg    float64
# Total Cost      float64
# Purchased        object
# dtype: object

# %%
weight_in_kg_column = df['Weight in Kg']


weight_in_kg_column
# Out:
# 0     44.0
# 1     27.0
# 2     30.0
# 3     38.0
# 4     40.0
# 5     35.0
# 6      NaN
# 7     48.0
# 8     50.0
# 9     37.0
# 10    47.0
# 11    39.0
# 12    46.0
# 13    29.0
# 14     NaN
# 15    24.0
# Name: Weight in Kg, dtype: float64

# %%
max_value = df['Weight in Kg'].max()


max_value
# Out:
# 50.0

# %%
filtered_data = df[df['Fruit Name'] == 'Strawberry']


filtered_data
# Out:
#     Fruit Name  Weight in Kg  Total Cost Purchased
# 3   Strawberry          38.0     61000.0        No
# 7   Strawberry          48.0     79000.0       Yes
# 8   Strawberry          50.0     83000.0        No
# 14  Strawberry           NaN     38500.0       Yes

# %%
import pandas as pd


fruits = pd.DataFrame({
    'x': [0],
    'Apple': [30],
    'Banana': [20]
})


fruits
# Out:
#    x  Apple  Banana
# 0  0     30      20

# %%
sales_fruits = pd.DataFrame({
    'x': ['Sales 2022', 'Sales 2023'],
    'Apple': [1000, 5000],
    'Banana': [700, 2000]
})

sales_fruits
# Out:
#             x  Apple  Banana
# 0  Sales 2022   1000     700
# 1  Sales 2023   5000    2000
